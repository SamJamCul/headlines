# %%
import numpy
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils
# load ascii text and covert to lowercase
filename = "headlines.txt"
raw_text = open(filename, 'r', encoding='utf-8').read()
raw_text = raw_text.lower()
# create mapping of unique chars to integers
chars = sorted(list(set(raw_text)))
char_to_int = dict((c, i) for i, c in enumerate(chars))
# summarize the loaded data
n_chars = len(raw_text)
n_vocab = len(chars)
# prepare the dataset of input to output pairs encoded as integers
seq_length = 100
dataX = []
dataY = []
for i in range(0, n_chars - seq_length, 1):
	seq_in = raw_text[i:i + seq_length]
	seq_out = raw_text[i + seq_length]
	dataX.append([char_to_int[char] for char in seq_in])
	dataY.append(char_to_int[seq_out])
n_patterns = len(dataX)
# reshape X to be [samples, time steps, features]
X = numpy.reshape(dataX, (n_patterns, seq_length, 1))
# normalize
X = X / float(n_vocab)
# one hot encode the output variable
y = np_utils.to_categorical(dataY)
# define the LSTM model
model = Sequential()
model.add(LSTM(256, input_shape=(X.shape[1], X.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam')
# define the checkpoint
filepath="weights-improvement-{epoch:02d}-{loss:.4f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

# %%
model.fit(X, y, epochs=20, batch_size=128, callbacks=callbacks_list)
# Out:
# WARNING:tensorflow:From /Users/samuelculley/opt/anaconda3/envs/headline/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/20
# 16054/16054 [==============================] - 127s 8ms/step - loss: 3.1472
#
# Epoch 00001: loss improved from inf to 3.14724, saving model to weights-improvement-01-3.1472.hdf5
# Epoch 2/20
# 16054/16054 [==============================] - 129s 8ms/step - loss: 3.0858
#
# Epoch 00002: loss improved from 3.14724 to 3.08578, saving model to weights-improvement-02-3.0858.hdf5
# Epoch 3/20
# 16054/16054 [==============================] - 123s 8ms/step - loss: 3.0779
#
# Epoch 00003: loss improved from 3.08578 to 3.07787, saving model to weights-improvement-03-3.0779.hdf5
# Epoch 4/20
# 16054/16054 [==============================] - 122s 8ms/step - loss: 3.0703
#
# Epoch 00004: loss improved from 3.07787 to 3.07029, saving model to weights-improvement-04-3.0703.hdf5
# Epoch 5/20
# 16054/16054 [==============================] - 121s 8ms/step - loss: 3.0521
#
# Epoch 00005: loss improved from 3.07029 to 3.05215, saving model to weights-improvement-05-3.0521.hdf5
# Epoch 6/20
# 16054/16054 [==============================] - 120s 7ms/step - loss: 3.0188
#
# Epoch 00006: loss improved from 3.05215 to 3.01877, saving model to weights-improvement-06-3.0188.hdf5
# Epoch 7/20
# 16054/16054 [==============================] - 120s 7ms/step - loss: 2.9819
#
# Epoch 00007: loss improved from 3.01877 to 2.98194, saving model to weights-improvement-07-2.9819.hdf5
# Epoch 8/20
# 16054/16054 [==============================] - 120s 7ms/step - loss: 2.9475
#
# Epoch 00008: loss improved from 2.98194 to 2.94748, saving model to weights-improvement-08-2.9475.hdf5
# Epoch 9/20
# 16054/16054 [==============================] - 119s 7ms/step - loss: 2.9202
#
# Epoch 00009: loss improved from 2.94748 to 2.92015, saving model to weights-improvement-09-2.9202.hdf5
# Epoch 10/20
# 16054/16054 [==============================] - 119s 7ms/step - loss: 2.8860
#
# Epoch 00010: loss improved from 2.92015 to 2.88595, saving model to weights-improvement-10-2.8860.hdf5
# Epoch 11/20
# 16054/16054 [==============================] - 118s 7ms/step - loss: 2.8470
#
# Epoch 00011: loss improved from 2.88595 to 2.84701, saving model to weights-improvement-11-2.8470.hdf5
# Epoch 12/20
# 16054/16054 [==============================] - 118s 7ms/step - loss: 2.8093
#
# Epoch 00012: loss improved from 2.84701 to 2.80932, saving model to weights-improvement-12-2.8093.hdf5
# Epoch 13/20
# 16054/16054 [==============================] - 118s 7ms/step - loss: 2.7601
#
# Epoch 00013: loss improved from 2.80932 to 2.76010, saving model to weights-improvement-13-2.7601.hdf5
# Epoch 14/20
# 16054/16054 [==============================] - 118s 7ms/step - loss: 2.7023
#
# Epoch 00014: loss improved from 2.76010 to 2.70226, saving model to weights-improvement-14-2.7023.hdf5
# Epoch 15/20
# 16054/16054 [==============================] - 118s 7ms/step - loss: 2.6525
#
# Epoch 00015: loss improved from 2.70226 to 2.65251, saving model to weights-improvement-15-2.6525.hdf5
# Epoch 16/20
# 16054/16054 [==============================] - 118s 7ms/step - loss: 2.6061
#
# Epoch 00016: loss improved from 2.65251 to 2.60614, saving model to weights-improvement-16-2.6061.hdf5
# Epoch 17/20
# 16054/16054 [==============================] - 118s 7ms/step - loss: 2.5651
#
# Epoch 00017: loss improved from 2.60614 to 2.56514, saving model to weights-improvement-17-2.5651.hdf5
# Epoch 18/20
# 16054/16054 [==============================] - 118s 7ms/step - loss: 2.5330
#
# Epoch 00018: loss improved from 2.56514 to 2.53302, saving model to weights-improvement-18-2.5330.hdf5
# Epoch 19/20
# 16054/16054 [==============================] - 118s 7ms/step - loss: 2.4946
#
# Epoch 00019: loss improved from 2.53302 to 2.49456, saving model to weights-improvement-19-2.4946.hdf5
# Epoch 20/20
# 16054/16054 [==============================] - 118s 7ms/step - loss: 2.4568
#
# Epoch 00020: loss improved from 2.49456 to 2.45678, saving model to weights-improvement-20-2.4568.hdf5
